# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Mock design configs

# %%
intrinsic_params = ["v", "a", "decay", "tau", "s_v", "s_tau"]

# %%
num_regressors = 5

for i in range(num_regressors):
    config = random.choice()
