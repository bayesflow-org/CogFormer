# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from BayesGPT.simulators.benchmarks.ddm import DDMFamily

# %%
ddm = DDMFamily()

# %%
ddm.simulators
# Out:
# [{'simulator': <function BayesGPT.simulators.benchmarks.ddm.__autoreload_class__._add_variants.<locals>.ddm_basic(drift, boundary)>,
#   'simulator_name': 'basic',
#   'variable_names': ['drift', 'boundary']},
#  {'simulator': <function BayesGPT.simulators.benchmarks.ddm.__autoreload_class__._add_variants.<locals>.ddm_with_ndt(drift, boundary, ndt)>,
#   'simulator_name': 'with_ndt',
#   'variable_names': ['drift', 'boundary', 'ndt']},
#  {'simulator': <function BayesGPT.simulators.benchmarks.ddm.__autoreload_class__._add_variants.<locals>.ddm_with_traj(drift, boundary, ndt)>,
#   'simulator_name': 'trajectory',
#   'variable_names': ['drift', 'boundary', 'ndt']},
#  {'simulator': <function BayesGPT.simulators.benchmarks.ddm.__autoreload_class__._add_variants.<locals>.ddm_collapsing_bound(drift, initial_boundary, ndt, collapse_rate)>,
#   'simulator_name': 'collapsing_bound',
#   'variable_names': ['drift', 'initial_boundary', 'ndt', 'collapse_rate']}]

# %%
params = {
    "drift": 0.5,
    "boundary": 1.0,
    "initial_boundary": 1.0,
    "ndt": 0.3,
    "collapse_rate": 0.01,
}

# %%
results = ddm.run(batch_size=10, **params)

# %%
results.get("trajectory")
# Out:
# [{'RT': 0.74,
#   'choice': 1,
#   'trajectory': [0,
#    0.02660832307717312,
#    0.15045692298333307,
#    0.19589206411855073,
#    0.16649904256517886,
#    0.24074883507290085,
#    0.21622009500254366,
#    0.1909011400594684,
#    0.12690718877507462,
#    0.14872661364053166,
#    0.039843197069257694,
#    -0.19705577992772966,
#    -0.10270378172862377,
#    -0.006107419751053361,
#    0.01583883879443144,
#    0.16731574735760238,
#    0.21269177884205254,
#    0.4648642112336194,
#    0.43395862390899953,
#    0.4334181533665575,
#    0.4439400843966723,
#    0.515519918362655,
#    0.6364827745321598,
#    0.4978048747746391,
#    0.508138809814533,
#    0.4568875022964376,
#    0.516652113650071,
#    0.5061468080967068,
#    0.6182144389600975,
#    0.594766418106031,
#    0.5778248728655222,
#    0.5894374098028846,
#    0.6490953946090177,
#    0.6769061564345796,
#    0.5397163920600655,
#    0.7555574821998389,
#    0.7244300558681492,
#    0.6905375595368161,
# ...
